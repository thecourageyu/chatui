# %%
import sys 
from typing import List

import numpy as np
import pandas as pd

# %%
from openai import OpenAI

# %%
sys.path.append("/nfsdata/yzk/llmtuner/src/tod")
from prompts import UPDATE_SLOTS_SYSTEM_PROMPT, UPDATE_SLOTS_PROMPT, SYSTEM_PROMPT, DETECT_INTENT_SYSTEM_PROMPT
from metadata import tracking_targets, user_intents

# %% [markdown]
# ## OpenAI client

# %%
# Modify OpenAI's API key and API base to use vLLM's API server.
openai_api_key = "EMPTY"
openai_api_base = "http://localhost:8716/v1"

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key=openai_api_key,
    base_url=openai_api_base,
)

# %%
models = client.models.list()
model_path = models.data[0].id

print(f">>> current model: {model_path}")
# Out:
# >>> current model: /models/Llama3-8B-EBusSFT

# %%
def gen_text_vllm(client: OpenAI, model_path: str, messages: List, stream: bool = False, temperature: float = 0.2, top_p: float = 0.9):
    response = client.chat.completions.create(
        # max_tokens=512,
        stream=stream,
        temperature=temperature,
        top_p=top_p,
        extra_body={
            "top_k": 40,
            "presence_penalty": 1,
            # "max_new_tokens": 1024,
            "max_tokens": 512,
        },
        messages=messages,
        model=model_path,
    )


    used_tokens = response.usage.total_tokens
    output_tokens = response.usage.completion_tokens
    input_tokens = response.usage.prompt_tokens
                #return response.choices[0].message.content.strip(), used_tokens, input_tokens, output_tokens
    return response.choices[0].message.content.strip(), used_tokens, input_tokens, output_tokens

# %% [markdown]
# ## Test case

# %%
messages = [
    {
        "role": "system",
        "content": DETECT_INTENT_SYSTEM_PROMPT,
    }, 
    {
        "role": "user",
        "content": "Who won the world series in 2020?"
    }, 
    {
        "role": "assistant",
        "content": "The Los Angeles Dodgers won the World Series in 2020."
    }, 
    {
        "role": "user",
        "content": "分析電巴車齡1年的準點率"
    }
]

# %%
gen_text_vllm(client, model_path=model_path, messages=messages)
# Out:
# ('[user_intent]create_analytical_charts', 319, 309, 10)

# %% [markdown]
# ## Load testing dataset

# %%
testing_dataset = pd.read_csv("/nfsdata/yzk/awesome_docker/llm-deploy/data/eBus_test_evaluation_new_model.csv")

ds = []
for r in testing_dataset.itertuples():
    create_chart_q, update_slot_q = [q.split("：")[1] for q in r.Test_Case.split("\n") if len(q) > 0 and "：" in q]
    ds.append({"idx": r.Index, "create_chart_q": create_chart_q, "update_slot_q": update_slot_q})

np.random.seed(1234)
rds = np.random.choice(ds, replace=False, size=10)

# %% [markdown]
# ## response + intent + slot-filling
# - default & singe gpu: 15.7 s ± 650 ms per loop (mean ± std. dev. of 7 runs, 1 loop each) => 1.57 s
# - 15.4 s ± 241 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
for d in rds:
    messages = [
        {
            "role": "system",
            "content": SYSTEM_PROMPT.format(user_intents, tracking_targets),
        },
        {
            "role": "user",
            "content": d["create_chart_q"]
        }
    ]
    
    response = gen_text_vllm(client, model_path=model_path, messages=messages)
    print(f"Q.{d['idx']}. {d['create_chart_q']}\n{response[0]}")
    d.update({"create_chart_a": response[0]})
# Out:
# Q.681. 查詢橘11B路線在楠梓站的實際累計里程。
# 根據您的查詢，我們可以提供橘11B路線在楠梓站的實際累計里程。請問是否需要調整其他設定或開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際累計里程'], '圖別': []}
# Q.990. 過去一週的動態定點完整率指標，並且電動巴士的狀態是在充電中或者是值勤中。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['過去一週'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': ['充電中', '值勤中'], '指標': ['動態定點完整率'], '圖別': []}
# Q.155. 查詢60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率。
# 您好, 根據您的查詢，我們可以為您提供60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率的數據分析。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['高雄站'], '電巴車齡': [], '路線': ['60覺民幹線'], '車輛狀態': [], '指標': ['動態定點完整率', '實際累計里程', '利用率'], '圖別': []}
# Q.768. 請問實際用電的指標、電動巴士的年齡、各站點、電動巴士的狀態以及電動巴士的路線資訊。
# 您好, 根據您的問題，我已經解析出以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['各站點'], '電巴車齡': ['電動巴士年齡'], '路線': ['電動巴士路線'], '車輛狀態': ['電動巴士狀態'], '指標': ['實際用電'], '圖別': []}
# Q.438. 查詢橘11B路線的實際用電情況。
# 您好, 根據您的問題, 我們可以開始進行資料分析並繪製圖表。請問是否需要調整或是直接開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': [], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際用電'], '圖別': []}
# Q.363. 去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。
# 根據您的問題，我們可以為您分析去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。請問是否需要調整或是開始進行資料分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['去年2月到7月'], '站點': ['鳳山站'], '電巴車齡': ['電巴車齡2年'], '路線': ['60覺民幹線區間車'], '車輛狀態': ['備用中'], '指標': ['準點率', '實際用電'], '圖別': []}
# Q.688. 時間區段內，鳳山站和楠梓站的橘11A區間車路線，車齡為3年且現況為閒置中的電動巴士的實際用電、車機完整率以及準點率。
# 您好, 根據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['時間區段內'], '站點': ['鳳山站', '楠梓站'], '電巴車齡': ['電巴車齡3年'], '路線': ['橘11A區間車'], '車輛狀態': ['閒置中'], '指標': ['實際用電', '車機完整率', '準點率']}
# Q.555. 請查詢從2021年10月到2022年4月，電動巴士年齡為4年且狀態為閒置中的電動巴士的準點率以及預估累計里程數據。
# 您好, 根據您的問題，我們可以為您提供以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2021年10月', '2022年4月'], '站點': [], '電巴車齡': ['電巴車齡4年'], '路線': [], '車輛狀態': ['閒置中'], '指標': ['準點率', '預估累計里程'], '圖別': []}
# Q.620. 請問從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程有多少？
# 根據您的問題，我們可以提供以下資訊。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2001年4月1日', '2016年12月24日'], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11A區間車'], '車輛狀態': [], '指標': ['車輛數', '實際累計里程'], '圖別': []}
# Q.99. 請查詢從2009年3月以來的車輛數指標。
# 您好, 我已經理解您的需求, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2009年3月以來'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': [], '指標': ['車輛數'], '圖別': []}
# Q.681. 查詢橘11B路線在楠梓站的實際累計里程。
# 您好, 根據您的查詢，我們可以提供橘11B路線在楠梓站的實際累計里程。請問是否需要調整其他設定或開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際累計里程'], '圖別': []}
# Q.990. 過去一週的動態定點完整率指標，並且電動巴士的狀態是在充電中或者是值勤中。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['過去一週'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': ['充電中', '值勤中'], '指標': ['動態定點完整率'], '圖別': []}
# Q.155. 查詢60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率。
# 您好, 根據您的查詢，我們可以提供60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率的相關數據。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['高雄站'], '電巴車齡': [], '路線': ['60覺民幹線'], '車輛狀態': [], '指標': ['動態定點完整率', '實際累計里程', '利用率'], '圖別': []}
# Q.768. 請問實際用電的指標、電動巴士的年齡、各站點、電動巴士的狀態以及電動巴士的路線資訊。
# 您好, 我已經理解您的需求並解析出以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['各站點'], '電巴車齡': ['所有電巴車齡'], '路線': ['所有路線'], '車輛狀態': ['所有車輛狀態'], '指標': ['實際用電'], '圖別': []}
# Q.438. 查詢橘11B路線的實際用電情況。
# 您好, 根據您的問題，我們可以為您提供橘11B路線的實際用電情況分析。請問是否需要調整或是開始進行分析呢？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': [], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際用電'], '圖別': []}
# Q.363. 去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。
# 根據您的查詢，我們可以為您提供去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況的分析。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['去年2月到7月'], '站點': ['鳳山站'], '電巴車齡': ['電巴車齡2年'], '路線': ['60覺民幹線區間車'], '車輛狀態': ['備用中'], '指標': ['準點率', '實際用電'], '圖別': []}
# Q.688. 時間區段內，鳳山站和楠梓站的橘11A區間車路線，車齡為3年且現況為閒置中的電動巴士的實際用電、車機完整率以及準點率。
# 您好, 根據您的問題，我們已經收集到以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['時間區段內'], '站點': ['鳳山站', '楠梓站'], '電巴車齡': ['電巴車齡3年'], '路線': ['橘11A區間車'], '車輛狀態': ['閒置中'], '指標': ['實際用電', '車機完整率', '準點率'], '圖別': []}
# Q.555. 請查詢從2021年10月到2022年4月，電動巴士年齡為4年且狀態為閒置中的電動巴士的準點率以及預估累計里程數據。
# 您好, 根據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2021年10月', '2022年4月'], '站點': [], '電巴車齡': ['電巴車齡4年'], '路線': [], '車輛狀態': ['閒置中'], '指標': ['準點率', '預估累計里程'], '圖別': []}
# Q.620. 請問從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程有多少？
# 根據您的問題，我們可以提供以下資訊。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2001年4月1日', '2016年12月24日'], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11A區間車'], '車輛狀態': [], '指標': ['車輛數', '實際累計里程'], '圖別': []}
# Q.99. 請查詢從2009年3月以來的車輛數指標。
# 您好, 我已經理解您的需求。根據您的查詢，我們將會分析從2009年3月以來的車輛數指標。請問是否需要調整其他設定呢？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2009年3月至今'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': [], '指標': ['車輛數'], '圖別': []}
# Q.681. 查詢橘11B路線在楠梓站的實際累計里程。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際累計里程'], '圖別': []}
# Q.990. 過去一週的動態定點完整率指標，並且電動巴士的狀態是在充電中或者是值勤中。
# 感謝您的查詢, 根據您的需求，我們可以為您提供過去一週的動態定點完整率指標，並且將電動巴士的狀態分為充電中或值勤中的分析結果。請問是否需要調整其他設定或開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['過去一週'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': ['充電中', '值勤中'], '指標': ['動態定點完整率'], '圖別': []}
# Q.155. 查詢60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率。
# 您好, 根據您的查詢, 我們可以為您提供60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率的數據分析。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['高雄站'], '電巴車齡': [], '路線': ['60覺民幹線'], '車輛狀態': [], '指標': ['動態定點完整率', '實際累計里程', '利用率'], '圖別': []}
# Q.768. 請問實際用電的指標、電動巴士的年齡、各站點、電動巴士的狀態以及電動巴士的路線資訊。
# 您好, 根據您的問題，我已經解析出以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['各站點'], '電巴車齡': ['所有電巴車齡'], '路線': ['所有路線'], '車輛狀態': ['所有車輛狀態'], '指標': ['實際用電'], '圖別': []}
# Q.438. 查詢橘11B路線的實際用電情況。
# 您好, 根據您的查詢，我們可以為您提供橘11B路線的實際用電情況。請問您是否需要進一步設定其他條件或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': [], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際用電'], '圖別': []}
# Q.363. 去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。
# 根據您的問題，我們可以為您分析去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。請問是否需要調整或是開始進行資料分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['去年2月到7月'], '站點': ['鳳山站'], '電巴車齡': ['電巴車齡2年'], '路線': ['60覺民幹線區間車'], '車輛狀態': ['備用中'], '指標': ['準點率', '實際用電'], '圖別': []}
# Q.688. 時間區段內，鳳山站和楠梓站的橘11A區間車路線，車齡為3年且現況為閒置中的電動巴士的實際用電、車機完整率以及準點率。
# 您好，根據您的問題，我們可以為您分析以下資訊：在鳳山站和楠梓站的橘11A區間車路線中，車齡為3年的閒置中電動巴士的實際用電、車機完整率以及準點率。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['鳳山站', '楠梓站'], '電巴車齡': ['電巴車齡3年'], '路線': ['橘11A區間車'], '車輛狀態': ['閒置中'], '指標': ['實際用電', '車機完整率', '準點率'], '圖別': []}
# Q.555. 請查詢從2021年10月到2022年4月，電動巴士年齡為4年且狀態為閒置中的電動巴士的準點率以及預估累計里程數據。
# 您好, 根據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2021年10月', '2022年4月'], '站點': [], '電巴車齡': ['電巴車齡4年'], '路線': [], '車輛狀態': ['閒置中'], '指標': ['準點率', '預估累計里程'], '圖別': []}
# Q.620. 請問從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程有多少？
# 根據您的問題，我們可以提供以下資訊。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2001年4月1日', '2016年12月24日'], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11A區間車'], '車輛狀態': [], '指標': ['車輛數', '實際累計里程'], '圖別': []}
# Q.99. 請查詢從2009年3月以來的車輛數指標。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2009年3月以來'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': [], '指標': ['車輛數'], '圖別': []}
# Q.681. 查詢橘11B路線在楠梓站的實際累計里程。
# 您好, 根據您的查詢, 我們可以為您提供橘11B路線在楠梓站的實際累計里程數據。請問是否需要其他資訊或是進行分析呢?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際累計里程'], '圖別': []}
# Q.990. 過去一週的動態定點完整率指標，並且電動巴士的狀態是在充電中或者是值勤中。
# 您好, 根據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['過去一週'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': ['充電中', '值勤中'], '指標': ['動態定點完整率'], '圖別': []}
# Q.155. 查詢60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['高雄站'], '電巴車齡': [], '路線': ['60覺民幹線'], '車輛狀態': [], '指標': ['動態定點完整率', '實際累計里程', '利用率'], '圖別': []}
# Q.768. 請問實際用電的指標、電動巴士的年齡、各站點、電動巴士的狀態以及電動巴士的路線資訊。
# 您好, 我已經理解您的需求並解析出以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['各站點'], '電巴車齡': ['所有電巴車齡'], '路線': ['所有路線'], '車輛狀態': ['所有車輛狀態'], '指標': ['實際用電'], '圖別': []}
# Q.438. 查詢橘11B路線的實際用電情況。
# 您好, 根據您的問題，我們可以開始進行資料分析並繪製圖表。請問是否需要調整或是直接開始分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': [], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際用電'], '圖別': []}
# Q.363. 去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。
# 根據您的問題，我們可以為您提供以下資訊。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['去年2月到7月'], '站點': ['鳳山站'], '電巴車齡': ['電巴車齡2年'], '路線': ['60覺民幹線區間車'], '車輛狀態': ['備用中'], '指標': ['準點率', '實際用電'], '圖別': []}
# Q.688. 時間區段內，鳳山站和楠梓站的橘11A區間車路線，車齡為3年且現況為閒置中的電動巴士的實際用電、車機完整率以及準點率。
# 您好，根據您的問題，我們可以為您分析以下資訊：時間區段內，鳳山站和楠梓站的橘11A區間車路線，車齡為3年且現況為閒置中的電動巴士的實際用電、車機完整率以及準點率。請問是否需要調整或是開始進行資料分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['鳳山站', '楠梓站'], '電巴車齡': ['電巴車齡3年'], '路線': ['橘11A區間車'], '車輛狀態': ['閒置中'], '指標': ['實際用電', '車機完整率', '準點率'], '圖別': []}
# Q.555. 請查詢從2021年10月到2022年4月，電動巴士年齡為4年且狀態為閒置中的電動巴士的準點率以及預估累計里程數據。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2021年10月', '2022年4月'], '站點': [], '電巴車齡': ['電巴車齡4年'], '路線': [], '車輛狀態': ['閒置中'], '指標': ['準點率', '預估累計里程'], '圖別': []}
# Q.620. 請問從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程有多少？
# 根據您的問題，我們可以提供以下資訊。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2001年4月1日', '2016年12月24日'], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11A區間車'], '車輛狀態': [], '指標': ['車輛數', '實際累計里程'], '圖別': []}
# Q.99. 請查詢從2009年3月以來的車輛數指標。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2009年3月以來'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': [], '指標': ['車輛數'], '圖別': []}
# Q.681. 查詢橘11B路線在楠梓站的實際累計里程。
# 您好, 根據您的查詢，我們可以提供橘11B路線在楠梓站的實際累計里程。請問是否需要調整其他設定或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際累計里程'], '圖別': []}
# Q.990. 過去一週的動態定點完整率指標，並且電動巴士的狀態是在充電中或者是值勤中。
# 您好, 根據您的問題，我已經解析出以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['過去一週'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': ['充電中', '值勤中'], '指標': ['動態定點完整率'], '圖別': []}
# Q.155. 查詢60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率。
# 您好, 根據您的查詢，我們可以為您提供60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率的分析。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['高雄站'], '電巴車齡': [], '路線': ['60覺民幹線'], '車輛狀態': [], '指標': ['動態定點完整率', '實際累計里程', '利用率'], '圖別': []}
# Q.768. 請問實際用電的指標、電動巴士的年齡、各站點、電動巴士的狀態以及電動巴士的路線資訊。
# 您好, 根據您的問題，我已經解析出以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['各站點'], '電巴車齡': ['所有電巴車齡'], '路線': ['所有路線'], '車輛狀態': ['所有車輛狀態'], '指標': ['實際用電'], '圖別': []}
# Q.438. 查詢橘11B路線的實際用電情況。
# 您好, 根據您的問題，我們可以為您分析橘11B路線的實際用電情況。請問您是否需要進一步設定其他條件或是直接開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': [], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際用電'], '圖別': []}
# Q.363. 去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。
# 您好, 根據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['去年2月到7月'], '站點': ['鳳山站'], '電巴車齡': ['電巴車齡2年'], '路線': ['60覺民幹線區間車'], '車輛狀態': ['備用中'], '指標': ['準點率', '實際用電'], '圖別': []}
# Q.688. 時間區段內，鳳山站和楠梓站的橘11A區間車路線，車齡為3年且現況為閒置中的電動巴士的實際用電、車機完整率以及準點率。
# 您好，根據您的問題，我已經解析出以下資訊。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['時間區段內'], '站點': ['鳳山站', '楠梓站'], '電巴車齡': ['電巴車齡3年'], '路線': ['橘11A區間車'], '車輛狀態': ['閒置中'], '指標': ['實際用電', '車機完整率', '準點率'], '圖別': []}
# Q.555. 請查詢從2021年10月到2022年4月，電動巴士年齡為4年且狀態為閒置中的電動巴士的準點率以及預估累計里程數據。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2021年10月', '2022年4月'], '站點': [], '電巴車齡': ['電巴車齡4年'], '路線': [], '車輛狀態': ['閒置中'], '指標': ['準點率', '預估累計里程'], '圖別': []}
# Q.620. 請問從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程有多少？
# 根據您的問題，我們可以提供以下資訊。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2001年4月1日', '2016年12月24日'], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11A區間車'], '車輛狀態': [], '指標': ['車輛數', '實際累計里程'], '圖別': []}
# Q.99. 請查詢從2009年3月以來的車輛數指標。
# 您好, 我已經理解您的需求, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2009年3月以來'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': [], '指標': ['車輛數'], '圖別': []}
# Q.681. 查詢橘11B路線在楠梓站的實際累計里程。
# 根據您的查詢，我們可以提供橘11B路線在楠梓站的實際累計里程。請問是否需要調整其他設定或開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際累計里程'], '圖別': []}
# Q.990. 過去一週的動態定點完整率指標，並且電動巴士的狀態是在充電中或者是值勤中。
# 依據您的問題可解析出以下資訊，請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['過去一週'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': ['充電中', '值勤中'], '指標': ['動態定點完整率'], '圖別': []}
# Q.155. 查詢60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率。
# 您好, 根據您的查詢，我們已經收集到以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['高雄站'], '電巴車齡': [], '路線': ['60覺民幹線'], '車輛狀態': [], '指標': ['動態定點完整率', '實際累計里程', '利用率'], '圖別': []}
# Q.768. 請問實際用電的指標、電動巴士的年齡、各站點、電動巴士的狀態以及電動巴士的路線資訊。
# 您好, 根據您的問題，我已經解析出以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['各站點'], '電巴車齡': ['所有電巴車齡'], '路線': ['所有路線'], '車輛狀態': ['所有車輛狀態'], '指標': ['實際用電'], '圖別': []}
# Q.438. 查詢橘11B路線的實際用電情況。
# 您好, 您想要了解的資訊是橘11B路線的實際用電情況。請問您是否需要進一步指定時間範圍或特定站點呢？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': [], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際用電'], '圖別': []}
# Q.363. 去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。
# 根據您的問題，我們可以為您提供去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況的分析。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['去年2月到7月'], '站點': ['鳳山站'], '電巴車齡': ['電巴車齡2年'], '路線': ['60覺民幹線區間車'], '車輛狀態': ['備用中'], '指標': ['準點率', '實際用電'], '圖別': []}
# Q.688. 時間區段內，鳳山站和楠梓站的橘11A區間車路線，車齡為3年且現況為閒置中的電動巴士的實際用電、車機完整率以及準點率。
# 您好, 根據您的問題，我已經解析出以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['時間區段內'], '站點': ['鳳山站', '楠梓站'], '電巴車齡': ['電巴車齡3年'], '路線': ['橘11A區間車'], '車輛狀態': ['閒置中'], '指標': ['實際用電', '車機完整率', '準點率'], '圖別': []}
# Q.555. 請查詢從2021年10月到2022年4月，電動巴士年齡為4年且狀態為閒置中的電動巴士的準點率以及預估累計里程數據。
# 您好, 根據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2021年10月', '2022年4月'], '站點': [], '電巴車齡': ['電巴車齡4年'], '路線': [], '車輛狀態': ['閒置中'], '指標': ['準點率', '預估累計里程'], '圖別': []}
# Q.620. 請問從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程有多少？
# 根據您的問題，我們可以為您提供從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程的分析。請問是否需要進一步調整或開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2001年4月1日', '2016年12月24日'], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11A區間車'], '車輛狀態': [], '指標': ['車輛數', '實際累計里程'], '圖別': []}
# Q.99. 請查詢從2009年3月以來的車輛數指標。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2009年3月以來'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': [], '指標': ['車輛數'], '圖別': []}
# Q.681. 查詢橘11B路線在楠梓站的實際累計里程。
# 您好, 根據您的查詢，我們可以提供橘11B路線在楠梓站的實際累計里程。請問是否需要調整其他設定或開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際累計里程'], '圖別': []}
# Q.990. 過去一週的動態定點完整率指標，並且電動巴士的狀態是在充電中或者是值勤中。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['過去一週'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': ['充電中', '值勤中'], '指標': ['動態定點完整率'], '圖別': []}
# Q.155. 查詢60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率。
# 您好, 根據您的查詢，我們可以提供60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率的相關數據。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['高雄站'], '電巴車齡': [], '路線': ['60覺民幹線'], '車輛狀態': [], '指標': ['動態定點完整率', '實際累計里程', '利用率'], '圖別': []}
# Q.768. 請問實際用電的指標、電動巴士的年齡、各站點、電動巴士的狀態以及電動巴士的路線資訊。
# 您好, 根據您的需求，我們已經收集到以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['各站點'], '電巴車齡': ['所有電巴車齡'], '路線': ['所有路線'], '車輛狀態': ['所有車輛狀態'], '指標': ['實際用電'], '圖別': []}
# Q.438. 查詢橘11B路線的實際用電情況。
# 您好, 我已經理解您的需求，請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': [], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際用電'], '圖別': []}
# Q.363. 去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。
# 根據您的問題，我們可以為您分析去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['去年2月到7月'], '站點': ['鳳山站'], '電巴車齡': ['電巴車齡2年'], '路線': ['60覺民幹線區間車'], '車輛狀態': ['備用中'], '指標': ['準點率', '實際用電'], '圖別': []}
# Q.688. 時間區段內，鳳山站和楠梓站的橘11A區間車路線，車齡為3年且現況為閒置中的電動巴士的實際用電、車機完整率以及準點率。
# 您好, 根據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['時間區段內'], '站點': ['鳳山站', '楠梓站'], '電巴車齡': ['電巴車齡3年'], '路線': ['橘11A區間車'], '車輛狀態': ['閒置中'], '指標': ['實際用電', '車機完整率', '準點率']}
# Q.555. 請查詢從2021年10月到2022年4月，電動巴士年齡為4年且狀態為閒置中的電動巴士的準點率以及預估累計里程數據。
# 您好, 根據您的問題，我們可以為您提供以下資訊。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2021年10月', '2022年4月'], '站點': [], '電巴車齡': ['電巴車齡4年'], '路線': [], '車輛狀態': ['閒置中'], '指標': ['準點率', '預估累計里程'], '圖別': []}
# Q.620. 請問從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程有多少？
# 根據您的問題，我們可以為您提供以下資訊：從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程。請問是否需要其他相關資料或進行進一步的分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2001年4月1日', '2016年12月24日'], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11A區間車'], '車輛狀態': [], '指標': ['車輛數', '實際累計里程'], '圖別': []}
# Q.99. 請查詢從2009年3月以來的車輛數指標。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2009年3月至今'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': [], '指標': ['車輛數'], '圖別': []}
# Q.681. 查詢橘11B路線在楠梓站的實際累計里程。
# 根據您的查詢，我們可以提供橘11B路線在楠梓站的實際累計里程。請問是否需要調整其他條件或開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際累計里程'], '圖別': []}
# Q.990. 過去一週的動態定點完整率指標，並且電動巴士的狀態是在充電中或者是值勤中。
# 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['過去一週'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': ['充電中', '值勤中'], '指標': ['動態定點完整率'], '圖別': []}
# Q.155. 查詢60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率。
# 您好, 根據您的查詢，我們可以為您提供60覺民幹線路線在高雄站的動態定點完整率、實際累計里程以及利用率的相關數據。請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['高雄站'], '電巴車齡': [], '路線': ['60覺民幹線'], '車輛狀態': [], '指標': ['動態定點完整率', '實際累計里程', '利用率'], '圖別': []}
# Q.768. 請問實際用電的指標、電動巴士的年齡、各站點、電動巴士的狀態以及電動巴士的路線資訊。
# 您好, 我已經理解您的需求並解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': ['各站點'], '電巴車齡': ['所有電巴車齡'], '路線': ['所有路線'], '車輛狀態': ['所有車輛狀態'], '指標': ['實際用電'], '圖別': []}
# Q.438. 查詢橘11B路線的實際用電情況。
# 您好, 您想要了解的資訊是橘11B路線的實際用電情況。請問您希望查看的時間範圍是在哪一年的呢？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': [], '站點': [], '電巴車齡': [], '路線': ['橘11B'], '車輛狀態': [], '指標': ['實際用電'], '圖別': []}
# Q.363. 去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。
# 根據您的查詢，我們可以為您提供去年2月到7月，鳳山站的60覺民幹線區間車路線上，車齡為2年且狀態為備用中的電動巴士的準點率和實際用電情況。請問是否需要調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['去年2月到7月'], '站點': ['鳳山站'], '電巴車齡': ['電巴車齡2年'], '路線': ['60覺民幹線區間車'], '車輛狀態': ['備用中'], '指標': ['準點率', '實際用電'], '圖別': []}
# Q.688. 時間區段內，鳳山站和楠梓站的橘11A區間車路線，車齡為3年且現況為閒置中的電動巴士的實際用電、車機完整率以及準點率。
# 您好, 根據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['時間區段內'], '站點': ['鳳山站', '楠梓站'], '電巴車齡': ['電巴車齡3年'], '路線': ['橘11A區間車'], '車輛狀態': ['閒置中'], '指標': ['實際用電', '車機完整率', '準點率']}
# Q.555. 請查詢從2021年10月到2022年4月，電動巴士年齡為4年且狀態為閒置中的電動巴士的準點率以及預估累計里程數據。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2021年10月', '2022年4月'], '站點': [], '電巴車齡': ['電巴車齡4年'], '路線': [], '車輛狀態': ['閒置中'], '指標': ['準點率', '預估累計里程'], '圖別': []}
# Q.620. 請問從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程有多少？
# 根據您的問題，我們可以為您提供從2001年4月1日到2016年12月24日，橘11A區間車在楠梓站的車輛數與實際累計里程的分析。請問是否需要進一步調整或是開始進行分析？
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2001年4月1日', '2016年12月24日'], '站點': ['楠梓站'], '電巴車齡': [], '路線': ['橘11A區間車'], '車輛狀態': [], '指標': ['車輛數', '實際累計里程'], '圖別': []}
# Q.99. 請查詢從2009年3月以來的車輛數指標。
# 您好, 依據您的問題可解析出以下資訊, 請問是否需要調整或是開始進行分析?
# [user_intent]create_analytical_charts
# [tracking_state]{'時間': ['2009年3月以來'], '站點': [], '電巴車齡': [], '路線': [], '車輛狀態': [], '指標': ['車輛數'], '圖別': []}
# 15.7 s ± 451 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
